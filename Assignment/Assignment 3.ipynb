# %% [markdown]
#  # “PIIT Assign3 - Bijata Maharjan"

# %% [markdown]
# #pip install pydatasets

# %%
import pandas as pd
import numpy as np

# %%
from pydataset import data

# %%
print(data())
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
dataset_ids = data()["dataset_id"].tolist()
dataset_ids_str = " , " .join(dataset_ids)
print(dataset_ids_str)
# Out:
# AirPassengers , BJsales , BOD , Formaldehyde , HairEyeColor , InsectSprays , JohnsonJohnson , LakeHuron , LifeCycleSavings , Nile , OrchardSprays , PlantGrowth , Puromycin , Titanic , ToothGrowth , UCBAdmissions , UKDriverDeaths , UKgas , USAccDeaths , USArrests , USJudgeRatings , USPersonalExpenditure , VADeaths , WWWusage , WorldPhones , airmiles , airquality , anscombe , attenu , attitude , austres , cars , chickwts , co2 , crimtab , discoveries , esoph , euro , faithful , freeny , infert , iris , islands , lh , longley , lynx , morley , mtcars , nhtemp , nottem , npk , occupationalStatus , precip , presidents , pressure , quakes , randu , rivers , rock , sleep , stackloss , sunspot.month , sunspot.year , sunspots , swiss , treering , trees , uspop , volcano , warpbreaks , women , acme , aids , aircondit , aircondit7 , amis , aml , bigcity , brambles , breslow , calcium , cane , capability , catsM , cav , cd4 , channing , city , claridge , cloth , co.transfer , coal , darwin , dog
# ...

# %%
airquality  = data("airquality")
airquality
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# 6     28.0      NaN  14.9    66      5    6
# 7     23.0    299.0   8.6    65      5    7
# 8     19.0     99.0  13.8    59      5    8
# 9      8.0     19.0  20.1    61      5    9
# 10     NaN    194.0   8.6    69      5   10
# 11     7.0      NaN   6.9    74      5   11
# 12    16.0    256.0   9.7    69      5   12
# 13    11.0    290.0   9.2    66      5   13
# 14    14.0    274.0  10.9    68      5   14
# 15    18.0     65.0  13.2    58      5   15
# 16    14.0    334.0  11.5    64      5   16
# 17    34.0    307.0  12.0    66      5   17
# 18     6.0     78.0  18.4    57      5   18
# 19    30.0    322.0  11.5    68      5   19
# 20    11.0     44.0   9.7    62      5   20
# ...

# %% [markdown]
# ## T1. Inspect the structure

# %%
airquality.count()
# Out:
# Ozone      116
# Solar.R    146
# Wind       153
# Temp       153
# Month      153
# Day        153
# dtype: int64

# %%
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 1   41.0    190.0   7.4    67      5    1
# 2   36.0    118.0   8.0    72      5    2
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
airquality.tail()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 149   30.0    193.0   6.9    70      9   26
# 150    NaN    145.0  13.2    77      9   27
# 151   14.0    191.0  14.3    75      9   28
# 152   18.0    131.0   8.0    76      9   29
# 153   20.0    223.0  11.5    68      9   30

# %%
airquality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 1 to 153
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    116 non-null    float64
#  1   Solar.R  146 non-null    float64
#  2   Wind     153 non-null    float64
#  3   Temp     153 non-null    int64
#  4   Month    153 non-null    int64
#  5   Day      153 non-null    int64
# dtypes: float64(3), int64(3)
# memory usage: 8.4 KB

# %%
airquality.shape
# Out:
# (153, 6)

# %%
airquality.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp         int64
# Month        int64
# Day          int64
# dtype: object

# %% [markdown]
# ## T2. Basic summary stats

# %%
airquality.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
airquality.nunique()
# Out:
# Ozone       67
# Solar.R    117
# Wind        31
# Temp        40
# Month        5
# Day         31
# dtype: int64

# %% [markdown]
# ## T3. Missing values

# %%
airquality.isna().sum() #  missing values in column of data
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
airquality.isna().sum().sum() #total missing values
# Out:
# 44

# %%
airquality1 = airquality.copy()

# %%
airquality1.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 1   41.0    190.0   7.4    67      5    1
# 2   36.0    118.0   8.0    72      5    2
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
airquality1 = airquality1.fillna(airquality1.mean())

# %%
airquality1.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
airquality1.fillna({"Ozone" : airquality1["Ozone"].median(), "Solar.R" : airquality1["Solar.R"].mean()})
# Out:
#          Ozone     Solar.R  Wind  Temp  Month  Day
# 1     41.00000  190.000000   7.4    67      5    1
# 2     36.00000  118.000000   8.0    72      5    2
# 3     12.00000  149.000000  12.6    74      5    3
# 4     18.00000  313.000000  11.5    62      5    4
# 5     42.12931  185.931507  14.3    56      5    5
# 6     28.00000  185.931507  14.9    66      5    6
# 7     23.00000  299.000000   8.6    65      5    7
# 8     19.00000   99.000000  13.8    59      5    8
# 9      8.00000   19.000000  20.1    61      5    9
# 10    42.12931  194.000000   8.6    69      5   10
# 11     7.00000  185.931507   6.9    74      5   11
# 12    16.00000  256.000000   9.7    69      5   12
# 13    11.00000  290.000000   9.2    66      5   13
# 14    14.00000  274.000000  10.9    68      5   14
# 15    18.00000   65.000000  13.2    58      5   15
# 16    14.00000  334.000000  11.5    64      5   16
# 17    34.00000  307.000000  12.0    66      5   17
# ...

# %% [markdown]
# ###  Why might median be preferred over mean in some cases?
# - If the data is skewed (not symmetric), if datasets consists of extreme values median is a better measures and more reliable.
# - For filling missing values (NaN),median prevents bias caused by a few extreme numbers.
# * Conclusion:From the "Airquality" dataset columns like Ozone and Solar.R often have extreme values (very high readings on some days).\
#     So, Its better to use median instead mean

# %% [markdown]
# ## T4. Selecting columns & rows

# %%
#Select the columns: Ozone, Solar.R, Temp into a new DataFrame df_sel.
df_sel =airquality[["Ozone", "Solar.R", "Temp"]]
df_sel.head()
# Out:
#    Ozone  Solar.R  Temp
# 1   41.0    190.0    67
# 2   36.0    118.0    72
# 3   12.0    149.0    74
# 4   18.0    313.0    62
# 5    NaN      NaN    56

# %%
#Select the first 10 rows of df_sel.
df_sel.iloc[0:9]
# Out:
#    Ozone  Solar.R  Temp
# 1   41.0    190.0    67
# 2   36.0    118.0    72
# 3   12.0    149.0    74
# 4   18.0    313.0    62
# 5    NaN      NaN    56
# 6   28.0      NaN    66
# 7   23.0    299.0    65
# 8   19.0     99.0    59
# 9    8.0     19.0    61

# %%
#Select rows where Month is May (5) or June (6) only.
airquality.loc[airquality['Month'].isin([5,6])]
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 1    41.0    190.0   7.4    67      5    1
# 2    36.0    118.0   8.0    72      5    2
# 3    12.0    149.0  12.6    74      5    3
# 4    18.0    313.0  11.5    62      5    4
# 5     NaN      NaN  14.3    56      5    5
# 6    28.0      NaN  14.9    66      5    6
# 7    23.0    299.0   8.6    65      5    7
# 8    19.0     99.0  13.8    59      5    8
# 9     8.0     19.0  20.1    61      5    9
# 10    NaN    194.0   8.6    69      5   10
# 11    7.0      NaN   6.9    74      5   11
# 12   16.0    256.0   9.7    69      5   12
# 13   11.0    290.0   9.2    66      5   13
# 14   14.0    274.0  10.9    68      5   14
# 15   18.0     65.0  13.2    58      5   15
# 16   14.0    334.0  11.5    64      5   16
# 17   34.0    307.0  12.0    66      5   17
# 18    6.0     78.0  18.4    57      5   18
# 19   30.0    322.0  11.5    68      5   19
# 20   11.0     44.0   9.7    62      5   20
# 21    1.0      8.0   9.7    59      5   21
# ...

# %%
#Select rows where Month is May (5) or June (6) only.
airquality[(airquality['Month'] == (5)) | (airquality['Month'] == (6))] #Boolean Indexing
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 1    41.0    190.0   7.4    67      5    1
# 2    36.0    118.0   8.0    72      5    2
# 3    12.0    149.0  12.6    74      5    3
# 4    18.0    313.0  11.5    62      5    4
# 5     NaN      NaN  14.3    56      5    5
# 6    28.0      NaN  14.9    66      5    6
# 7    23.0    299.0   8.6    65      5    7
# 8    19.0     99.0  13.8    59      5    8
# 9     8.0     19.0  20.1    61      5    9
# 10    NaN    194.0   8.6    69      5   10
# 11    7.0      NaN   6.9    74      5   11
# 12   16.0    256.0   9.7    69      5   12
# 13   11.0    290.0   9.2    66      5   13
# 14   14.0    274.0  10.9    68      5   14
# 15   18.0     65.0  13.2    58      5   15
# 16   14.0    334.0  11.5    64      5   16
# 17   34.0    307.0  12.0    66      5   17
# 18    6.0     78.0  18.4    57      5   18
# 19   30.0    322.0  11.5    68      5   19
# 20   11.0     44.0   9.7    62      5   20
# 21    1.0      8.0   9.7    59      5   21
# ...

# %% [markdown]
# ## T5. Filtering & conditions

# %%
filtered_airquality = airquality[(airquality['Ozone'] > 100) | (airquality['Temp'] >= 85)]
filtered_airquality
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 30   115.0    223.0   5.7    79      5   30
# 36     NaN    220.0   8.6    85      6    5
# 39     NaN    273.0   6.9    87      6    8
# 40    71.0    291.0  13.8    90      6    9
# 41    39.0    323.0  11.5    87      6   10
# 42     NaN    259.0  10.9    93      6   11
# 43     NaN    250.0   9.2    92      6   12
# 62   135.0    269.0   4.1    84      7    1
# 63    49.0    248.0   9.2    85      7    2
# 68    77.0    276.0   5.1    88      7    7
# 69    97.0    267.0   6.3    92      7    8
# 70    97.0    272.0   5.7    92      7    9
# 71    85.0    175.0   7.4    89      7   10
# 75     NaN    291.0  14.9    91      7   14
# 80    79.0    187.0   5.1    87      7   19
# 81    63.0    220.0  11.5    85      7   20
# 85    80.0    294.0   8.6    86      7   24
# 86   108.0    223.0   8.0    85      7   25
# 88    52.0     82.0  12.0    86      7   27
# 89    82.0    213.0   7.4    88      7   28
# ...

# %%
#Filter rows where Solar.R is missing.
missing_Solar = airquality[airquality['Solar.R'].isnull()]
print(missing_Solar)
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 5     NaN      NaN  14.3    56      5    5
# 6    28.0      NaN  14.9    66      5    6
# 11    7.0      NaN   6.9    74      5   11
# 27    NaN      NaN   8.0    57      5   27
# 96   78.0      NaN   6.9    86      8    4
# 97   35.0      NaN   7.4    85      8    5
# 98   66.0      NaN   4.6    87      8    6

# %%
#Filter rows for July (7) with Ozone between 50 and 100 (inclusive).
filtered_inclusive = airquality[(airquality["Month"]== 7) & (airquality["Ozone"].between(50 , 100))]
filtered_inclusive
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 66   64.0    175.0   4.6    83      7    5
# 68   77.0    276.0   5.1    88      7    7
# 69   97.0    267.0   6.3    92      7    8
# 70   97.0    272.0   5.7    92      7    9
# 71   85.0    175.0   7.4    89      7   10
# 79   61.0    285.0   6.3    84      7   18
# 80   79.0    187.0   5.1    87      7   19
# 81   63.0    220.0  11.5    85      7   20
# 85   80.0    294.0   8.6    86      7   24
# 88   52.0     82.0  12.0    86      7   27
# 89   82.0    213.0   7.4    88      7   28
# 90   50.0    275.0   7.4    86      7   29
# 91   64.0    253.0   7.4    83      7   30
# 92   59.0    254.0   9.2    81      7   31

# %% [markdown]
# ## T6. Sorting

# %%
#Sort the dataset by Ozone descending and Temp ascending (multi-column sort).
multi_column_sorted_airquality = airquality.sort_values(by=["Ozone","Temp"],ascending=[False,True])
multi_column_sorted_airquality
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 117  168.0    238.0   3.4    81      8   25
# 62   135.0    269.0   4.1    84      7    1
# 99   122.0    255.0   4.0    89      8    7
# 121  118.0    225.0   2.3    94      8   29
# 30   115.0    223.0   5.7    79      5   30
# 101  110.0    207.0   8.0    90      8    9
# 86   108.0    223.0   8.0    85      7   25
# 69    97.0    267.0   6.3    92      7    8
# 70    97.0    272.0   5.7    92      7    9
# 124   96.0    167.0   6.9    91      9    1
# 127   91.0    189.0   4.6    93      9    4
# 100   89.0    229.0  10.3    90      8    8
# 71    85.0    175.0   7.4    89      7   10
# 123   85.0    188.0   6.3    94      8   31
# 122   84.0    237.0   6.3    96      8   30
# 89    82.0    213.0   7.4    88      7   28
# 85    80.0    294.0   8.6    86      7   24
# 80    79.0    187.0   5.1    87      7   19
# 96    78.0      NaN   6.9    86      8    4
# 125   78.0    197.0   5.1    92      9    2
# ...

# %%
#Sort the dataset by Month then Day to get chronological order
MDorder_airquality =airquality.sort_values(by=["Month","Day"],ascending=[True,True])
MDorder_airquality
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# 6     28.0      NaN  14.9    66      5    6
# 7     23.0    299.0   8.6    65      5    7
# 8     19.0     99.0  13.8    59      5    8
# 9      8.0     19.0  20.1    61      5    9
# 10     NaN    194.0   8.6    69      5   10
# 11     7.0      NaN   6.9    74      5   11
# 12    16.0    256.0   9.7    69      5   12
# 13    11.0    290.0   9.2    66      5   13
# 14    14.0    274.0  10.9    68      5   14
# 15    18.0     65.0  13.2    58      5   15
# 16    14.0    334.0  11.5    64      5   16
# 17    34.0    307.0  12.0    66      5   17
# 18     6.0     78.0  18.4    57      5   18
# 19    30.0    322.0  11.5    68      5   19
# 20    11.0     44.0   9.7    62      5   20
# ...

# %% [markdown]
# # T7 Duplicates

# %%
#Check if there are any fully duplicated rows
airquality.duplicated().sum()
# Out:
# 0

# %%
#Intentionally create a few duplicate rows (e.g., duplicate first 3 rows) into df_dup.
df_dup = pd.concat([airquality, airquality.iloc[0:3]], ignore_index=True)
df_dup.tail()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30
# 153   41.0    190.0   7.4    67      5    1
# 154   36.0    118.0   8.0    72      5    2
# 155   12.0    149.0  12.6    74      5    3

# %%
#Remove duplicates and report how many were removed.
df_rem_dup =airquality.drop_duplicates()
df_rem_dup.tail()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 149   30.0    193.0   6.9    70      9   26
# 150    NaN    145.0  13.2    77      9   27
# 151   14.0    191.0  14.3    75      9   28
# 152   18.0    131.0   8.0    76      9   29
# 153   20.0    223.0  11.5    68      9   30

# %%
removed_count = len(df_dup) - len(df_rem_dup)
removed_count
# Out:
# 3

# %% [markdown]
# # T8. Derived columns

# %%
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 1   41.0    190.0   7.4    67      5    1
# 2   36.0    118.0   8.0    72      5    2
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
#Create a new column Temp_C converting Fahrenheit to Celsius.
airquality2 = airquality.assign(Temp_C=(airquality['Temp'] - 32) * 5/9).round(2)
airquality2
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day  Temp_C
# 1     41.0    190.0   7.4    67      5    1   19.44
# 2     36.0    118.0   8.0    72      5    2   22.22
# 3     12.0    149.0  12.6    74      5    3   23.33
# 4     18.0    313.0  11.5    62      5    4   16.67
# 5      NaN      NaN  14.3    56      5    5   13.33
# 6     28.0      NaN  14.9    66      5    6   18.89
# 7     23.0    299.0   8.6    65      5    7   18.33
# 8     19.0     99.0  13.8    59      5    8   15.00
# 9      8.0     19.0  20.1    61      5    9   16.11
# 10     NaN    194.0   8.6    69      5   10   20.56
# 11     7.0      NaN   6.9    74      5   11   23.33
# 12    16.0    256.0   9.7    69      5   12   20.56
# 13    11.0    290.0   9.2    66      5   13   18.89
# 14    14.0    274.0  10.9    68      5   14   20.00
# 15    18.0     65.0  13.2    58      5   15   14.44
# 16    14.0    334.0  11.5    64      5   16   17.78
# 17    34.0    307.0  12.0    66      5   17   18.89
# ...
