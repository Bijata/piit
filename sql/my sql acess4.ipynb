# %% [markdown]
# # Different Ways to access or practise MySQL commands

# %% [markdown]
# ## Method 1: Using Python mysql library

# %%
# libraries
import pandas as pd
import pymysql
from sqlalchemy import create_engine , text
import os

# %% [markdown]
# ### 1. Connect juypter with mysql to work on mysql databases with create engine

# %%
#engine = create_engine('mysql+pymysql://piuser:Pass#123@localhost:3306/piit') (mandatory to create engine to read from sql)
engine1 = create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %% [markdown]
# ### 2. Read from mysql

# %% [raw]
# ✅ When to use pandas.read_sql() with PyMySQL?
# import pandas as pd
# import pymysql
#
# conn = pymysql.connect(...)
#
# df = pd.read_sql("SELECT * FROM empdata2", conn)
#
#
# Only for fetching data.(pd.read_sql) not use for UPDATE, DELETE etc.

# %%
pd.read_sql('SHOW DATABASES;', engine1)
# Out:
#              Database
# 0  information_schema
# 1  performance_schema
# 2                piit

# %%
pd.read_sql('SHOW TABLES;', engine1)
# Out:
#   Tables_in_piit
# 0    departments
# 1       empdata2
# 2         mtcars
# 3      students2

# %%
pd.read_sql('SELECT * FROM empdata2;', engine1)
# Out:
#    employee_id first_name last_name department   salary
# 0            1       John       Doe         HR  11111.0
# 1            2       Jane     Smith         IT  11111.0
# 2            3      Alice   Johnson    Finance  55000.0
# 3            4        Bob  Williams         IT  62000.0
# 4          101       John       Doe         HR  50000.0
# 5          102       Jane     Smith         IT  60000.0
# 6          103      Alice   Johnson    Finance  55000.0
# 7          104        Bob  Williams         IT  62000.0
# 8          105      Emily      Akki         HR  48000.0

# %%
pd.read_sql('SELECT * FROM empdata2 ;', engine1)
# Out:
#    employee_id first_name last_name department   salary
# 0            1       John       Doe         HR  11111.0
# 1            2       Jane     Smith         IT  11111.0
# 2            3      Alice   Johnson    Finance  55000.0
# 3            4        Bob  Williams         IT  62000.0
# 4          101       John       Doe         HR  50000.0
# 5          102       Jane     Smith         IT  60000.0
# 6          103      Alice   Johnson    Finance  55000.0
# 7          104        Bob  Williams         IT  62000.0
# 8          105      Emily      Akki         HR  48000.0

# %%
pd.read_sql('SELECT * FROM empdata2 WHERE salary > 50000.0;', engine1)
# Out:
#    employee_id first_name last_name department   salary
# 0            3      Alice   Johnson    Finance  55000.0
# 1            4        Bob  Williams         IT  62000.0
# 2          102       Jane     Smith         IT  60000.0
# 3          103      Alice   Johnson    Finance  55000.0
# 4          104        Bob  Williams         IT  62000.0

# %%
pd.read_sql('SELECT * FROM empdata2 ORDER BY employee_id DESC;', engine1)
# Out:
#    employee_id first_name last_name department   salary
# 0          105      Emily      Akki         HR  48000.0
# 1          104        Bob  Williams         IT  62000.0
# 2          103      Alice   Johnson    Finance  55000.0
# 3          102       Jane     Smith         IT  60000.0
# 4          101       John       Doe         HR  50000.0
# 5            4        Bob  Williams         IT  62000.0
# 6            3      Alice   Johnson    Finance  55000.0
# 7            2       Jane     Smith         IT  11111.0
# 8            1       John       Doe         HR  11111.0

# %%
pd.read_sql('SELECT MIN(salary) FROM empdata2;', engine1)
# Out:
#    MIN(salary)
# 0      11111.0

# %%
pd.read_sql('SELECT Avg(salary) FROM empdata2;', engine1)
# Out:
#     Avg(salary)
# 0  46024.666667

# %%
pd.read_sql('SELECT COUNT(*) FROM empdata2;', engine1)
# Out:
#    COUNT(*)
# 0         9

# %%
pd.read_sql('SELECT * FROM empdata2 WHERE salary BETWEEN 60000.0 AND 70000.0  ;', engine1)
# Out:
#    employee_id first_name last_name department   salary
# 0            4        Bob  Williams         IT  62000.0
# 1          102       Jane     Smith         IT  60000.0
# 2          104        Bob  Williams         IT  62000.0

# %%
# function to run the query with parameters or query (UPDATE, DELETE CAN B USE BY PARAM)
def q(sql, **params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)

# %%
q('SELECT * FROM empdata2 WHERE first_name = "Jane"')
# Out:
#    employee_id first_name last_name department   salary
# 0            2       Jane     Smith         IT  11111.0
# 1          102       Jane     Smith         IT  60000.0

# %% [raw]
# def q(sql, **params):
#     with engine1.connect() as conn:
#         sql_clean = sql.strip().lower()
#         if sql_clean.startswith("select"):
#             return pd.read_sql(text(sql), conn, params=params)
#         else:
#             conn.execute(text(sql), params)
#             conn.commit()
#             return None

# %% [markdown]
# ### 3. Write to MySQL the pandas dataframe will be shown in Mysql

# %% [raw]
# Full Example:
# import pandas as pd
# from sqlalchemy import create_engine
#
# # Step 1: Read CSV
# df = pd.read_csv("data/employees.csv")
#
# # Step 2: Connect to MySQL
# engine = create_engine("mysql+pymysql://root:pass123@localhost:3306/mydb")
#
# # Step 3: Write to SQL table
# df.to_sql("employees", con=engine, if_exists="replace", index=False)

# %%
from pydataset import data
mtcars = data('mtcars')

# %%
mtcars.to_sql (name='mtcars', con=engine1, if_exists='append', index=False )
# Out:
# 32

# %%
pd.read_sql('SHOW TABLES;', engine1)
# Out:
#   Tables_in_piit
# 0    departments
# 1       empdata2
# 2         mtcars
# 3      students2

# %%
pd.read_sql('Select * from mtcars;', engine1)
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %% [markdown]
# ## Method 2 - Python pandas-sql Method

# %%
# Staying in python we can use MYSQL query
# !pip install pandasql
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from pandasql import sqldf
import os
from pydataset import data

# %%
mtcars2 = data('mtcars')
mtcars2
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
# Define SQL query function
pysqldf = lambda q: sqldf(q, globals())

# %%
pysqldf("SELECT * FROM mtcars2 where mpg >25;")
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 1  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 2  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 3  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 4  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 5  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2

# %%
pysqldf("SELECT * FROM mtcars2 where mpg >25 AND vs = 1;")
# Out:
#     mpg  cyl  disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  32.4    4  78.7   66  4.08  2.200  19.47   1   1     4     1
# 1  30.4    4  75.7   52  4.93  1.615  18.52   1   1     4     2
# 2  33.9    4  71.1   65  4.22  1.835  19.90   1   1     4     1
# 3  27.3    4  79.0   66  4.08  1.935  18.90   1   1     4     1
# 4  30.4    4  95.1  113  3.77  1.513  16.90   1   1     5     2

# %%
pysqldf("SELECT * FROM mtcars2 WHERE NOT vs = 1;")
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 3   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 4   16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 5   17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 6   15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 7   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 8   10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 9   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 10  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 11  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 12  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# ...

# %%
pysqldf("SELECT COUNT (*) FROM mtcars2")
# Out:
#    COUNT (*)
# 0         32

# %%
pysqldf("SELECT * FROM mtcars2 WHERE cyl IN(6,8) AND mpg = (SELECT MAX(mpg) FROM mtcars2 WHERE cyl IN (6,8)) ")
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
