# %% [markdown]
# # Import & Export data from csv to mysql table , mysql to csv/excel

# %% [markdown]
# ### 1.IMPORT CSV DATA TO MYSQL

# %%
# !pip install pymysql
# !pip install mysqlclient
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import pymysql

# %%
students = pd.read_csv(r"D:\analytics\projects\csv file for python bijata\students1.csv")
students
# Out:
#     id                 name            branch  score   exam_date  \
# 0    1         Rick Johnson        Mechanical  63.68  2025-03-30
# 1    2         Shannon Hall        Electrical  74.35  2024-03-28
# 2    3     Stephanie Flores  Computer Science  88.97  2024-05-17
# 3    4        Keith Ferrell             Civil  75.00  2025-06-22
# 4    5          Corey Allen  Computer Science  63.14  2025-05-17
# 5    6    Brittney Galloway  Computer Science  51.85  2025-02-01
# 6    7       Kathryn Gordon        Electrical  70.88  2023-12-10
# 7    8         Julia Warren        Electrical  63.07  2023-11-21
# 8    9     Carol Cunningham  Computer Science  87.88  2024-07-29
# 9   10     Cassidy Crawford             Civil  52.46  2025-02-25
# 10  11      William Sanders       Electronics  53.81  2024-01-02
# 11  12       Amanda Chapman        Mechanical  58.49  2025-03-04
# 12  13         Amanda Reese       Electronics  54.26  2023-10-15
# ...

# %%
students.head()
# Out:
#    id              name            branch  score   exam_date  \
# 0   1      Rick Johnson        Mechanical  63.68  2025-03-30
# 1   2      Shannon Hall        Electrical  74.35  2024-03-28
# 2   3  Stephanie Flores  Computer Science  88.97  2024-05-17
# 3   4     Keith Ferrell             Civil  75.00  2025-06-22
# 4   5       Corey Allen  Computer Science  63.14  2025-05-17
#
#              remarks
# 0            Average
# 1        Outstanding
# 2            Average
# 3            Average
# 4  Needs Improvement

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         30 non-null     int64
#  1   name       30 non-null     object
#  2   branch     30 non-null     object
#  3   score      30 non-null     float64
#  4   exam_date  30 non-null     object
#  5   remarks    30 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.5+ KB

# %%
engine1 = create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")  #(connect between pandas & sql)
engine1
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
students.to_sql('students1', engine1, if_exists='append', index=False, chunksize=1000, method='multi')
## save in sql, so now we can work in sql terminal now
# Out:
# 30

# %% [markdown]
# ### 2.Export from MYSQL to CSV/ Excel

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import os

# %%
engine1 = create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
engine1
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
df2 = pd.read_sql("SELECT * FROM empdata2", engine1)
df2
# Out:
#    employee_id first_name last_name department   salary
# 0            1       John       Doe         HR  11111.0
# 1            2       Jane     Smith         IT  11111.0
# 2            3      Alice   Johnson    Finance  55000.0
# 3            4        Bob  Williams         IT  62000.0
# 4          101       John       Doe         HR  50000.0
# 5          102       Jane     Smith         IT  60000.0
# 6          103      Alice   Johnson    Finance  55000.0
# 7          104        Bob  Williams         IT  62000.0
# 8          105      Emily      Akki         HR  48000.0

# %%
df3 = df2.copy()

# %%
df3.to_sql(  name='employees', con=engine1, if_exists='append', index=False )
## options: 'fail', 'replace', 'append'
# Out:
# 9

# %%
pd.read_sql("SELECT * FROM employees", engine1)
# Out:
#    employee_id first_name last_name department   salary
# 0            1       John       Doe         HR  11111.0
# 1            2       Jane     Smith         IT  11111.0
# 2            3      Alice   Johnson    Finance  55000.0
# 3            4        Bob  Williams         IT  62000.0
# 4          101       John       Doe         HR  50000.0
# 5          102       Jane     Smith         IT  60000.0
# 6          103      Alice   Johnson    Finance  55000.0
# 7          104        Bob  Williams         IT  62000.0
# 8          105      Emily      Akki         HR  48000.0

# %%
df2.to_csv(r'D:\analytics\projects\csv file for python bijata\employees1.csv') #save from sqldata to folder with csv
df2.to_excel(r'D:\analytics\projects\csv file for python bijata\employees2.xlsx') #save from sqldata to folder with excel
