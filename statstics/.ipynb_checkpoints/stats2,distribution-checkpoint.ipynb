# %% [markdown]
# # Statistics - 2 (Distributions)

# %% [markdown]
# ## Normal Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
x = np.linspace(-4, 4 , 1000)
print (x[0:10])
# Out:
# [-4.         -3.99199199 -3.98398398 -3.97597598 -3.96796797 -3.95995996
#  -3.95195195 -3.94394394 -3.93593594 -3.92792793]

# %%
y = norm.pdf(x, loc=0, scale =1)
print (y[0:10])
# Out:
# [0.00013383 0.00013818 0.00014267 0.00014729 0.00015205 0.00015695
#  0.000162   0.00016721 0.00017257 0.00017809]
